# %%
menu_list = [
    {'name': '에스프레소','price':'2000','cag':'커피'},
{'name':'아메리카노','price':'2500','cag':'커피'},
{'name':'카푸치노','price':'3500','cag':'라떼'},
{'name':'카페라떼','price':'3500','cag':'라떼'},
{'name':'모카라떼','price':'4000','cag':'라떼'},
{'name':'바닐라라떼','price':'4000','cag':'라떼'},
{'name':'소이라떼','price':'4500','cag':'라떼'},
{'name':'피넛라떼','price':'4500','cag':'라떼'},
{'name':'토피넛라떼','price':'5000','cag':'라떼'},
{'name':'화이트모카','price':'5000','cag':'라떼'},
{'name':'카라멜마끼아또','price':'5000','cag':'라떼'},
{'name':'프라프치노','price':'6000','cag':'라떼'},
{'name':'핫초코','price':'5000','cag':'디카페인'},
{'name':'레몬에이드','price':'4500','cag':'에이드'},
{'name':'청포도에이드','price':'4500','cag':'에이드'},
{'name':'자몽에이드','price':'4500','cag':'에이드'},
{'name':'스무디','price':'4000','cag':'스무디'},
{'name':'망고스무디','price':'4500','cag':'스무디'},
{'name':'딸기스무디','price':'4500','cag':'스무디'},
{'name':'초코쿠키','price':'2000','cag':'디저트'},
{'name':'화이트쿠키','price':'2000','cag':'디저트'},
{'name':'피넛쿠키','price':'2000','cag':'디저트'},
{'name':'당큰케이크','price':'5000','cag':'디저트'},
{'name':'초코케이크','price':'5000','cag':'디저트'},
{'name':'치즈케이크','price':'5000','cag':'디저트'},
]

# %%
def price():
    min_price = int(input("최저 가격을 입력하세요 : "))
    max_price = int(input("최고 가격을 입력하세요 : "))
    
    for menu in menu_list:
        if min_price <= menu[price] <= max_price:
            print(f'{menu[name], {menu[price]}, {menu[cag]}}')
