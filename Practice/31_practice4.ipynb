# %%
f = open('data1.txt', 'w', encoding='utf-8')
f.write('Life is too short\n')
f.write('So, you need Python.\n')
f.write('Python is easy,\n')
f.write('and useful on many fiedls.')
f.close()

# %%
f = open('data1.txt', 'r' , encoding='utf-8')
data1 = f.read()
f.close()

print(data1)
# Out:
# Life is too short
# So, you need Python.
# Python is easy,
# and useful on many fiedls.

# %%
with open('data1.txt', 'r', encoding='utf-8') as f:
    data1 = f.read()

data1
# Out:
# 'Life is too short\nSo, you need Python.\nPython is easy,\nand useful on many fiedls.'

# %%
with open('guest.txt, 'a') as f 
name = input('name : ')

print('{name} welcome!!')
# Out:
#   Cell In[5], line 1
#     with open('guest.txt, 'a') as f
#                             ^
# SyntaxError: unterminated string literal (detected at line 1)
